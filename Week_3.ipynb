# %% [markdown]
# # Week 3 handin

# %% [markdown]
# ## Assignment
# Exercise 3

# %% [markdown]
# ## Status
# I completed all exercises.

# %% [markdown]
# ### Exercise 1

# %%
# Random student generator   
import random

ranListOfNames = ["Albert", "Brian", "Carsten", "Danny", "Frederik", "Anna", "Birte", "Carinna", "Dorte", "Frederikke"]

ranListOfImage_urls = ["HappyImage", "SadImage", "PuppyImage", "AnotherImage", "HelloWorldImage"]

ranListOfGrades = ["A+", "A", "A-", "B+", "B", "B-", "C+", "C", "C-"]

ranCourses = ["Python", "Unity", "Security"]

ranGender = ["Male", "Female"]

# Student class
class Student():
    
    def __init__(self, name, gender, data_sheet, image_url):
        self.name = name
        self.gender = gender
        self.data_sheet = data_sheet
        self.image_url = image_url
        
    def __repr__(self):
        return 'Student: {} {} {} {}'.format(self.name, self.gender, self.data_sheet, self.image_url)
    
    def get_avg_grade(listOfGrades):
        avg_value = sum(listOfGrades) / len(listOfGrades)
        
# DataSheet class
class DataSheet():    
    
    def __init__(self, courses=[]):
        self.courses = courses
    
    def __repr__(self):
        return 'DataSheet: {}'.format(self.courses)
    
    def get_grades_as_list(self):
        grades = []
        for course in self.courses:
            grades.append(course.grade)
            return grades

# Course class
class Course():
    
    def __init__(self, name, classroom, teacher, ETCS, grade=None):
        self.name = name
        self.classroom = classroom
        self.teacher = teacher
        self.ETCS = ETCS
        self.grade = grade
    
    def __repr__(self):
        return 'Course: {} {} {} {} {}'.format(self.name, self.classroom, self.teacher, self.ETCS, self.grade)

def rngStudent():
    studentAdded = []
    ranNum = random.randrange(1, 25)
    print(ranNum, "Students got added:")
    for n in range(ranNum):
        studentAdded.append(Student(random.choice(ranListOfNames), 
                                    random.choice(ranGender),
                                    random.choice(ranCourses),
                                    random.choice(ranListOfImage_urls)))
                                    #random.choice(ranListOfGrades)!!!!!!!!!!!!!!!!!!!!!!!!
    print(studentAdded)
        
rngStudent()
# Out:
# 11 Students got added:
# [Student: Albert Male Unity AnotherImage, Student: Danny Male Python PuppyImage, Student: Brian Female Security AnotherImage, Student: Danny Female Python HappyImage, Student: Frederik Female Unity SadImage, Student: Birte Female Python HelloWorldImage, Student: Birte Male Python HappyImage, Student: Frederik Male Python HappyImage, Student: Frederikke Male Security HelloWorldImage, Student: Frederikke Male Python HappyImage, Student: Brian Female Unity SadImage]

# %% [markdown]
# ## 04 Solution part 2
